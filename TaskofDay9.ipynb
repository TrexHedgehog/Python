# %%
# Task - 9

# %%
# Linked List Reversal Exercise
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, value):
        if not self.head:
            self.head = Node(value)
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = Node(value)

    def reverse(self):
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev
        return self.head
    
    def display(self):
        current = self.head
        while current:
            print(current.value, end=" ")
            current = current.next
        print()
if __name__ == "__main__":
    linked_list = LinkedList()
    linked_list.append(1)
    linked_list.append(2)
    linked_list.append(3)
    linked_list.append(4)
    linked_list.append(5)

    print("Original linked list:")
    linked_list.display()

    linked_list.reverse()

    print("Reversed linked list:")
    linked_list.display()
# Out:
# Original linked list:
# 1 2 3 4 5
# Reversed linked list:
# 5 4 3 2 1

# %%
# Exercises for Threading in Python

import threading
import time

def countdown_timer(name, seconds):
    print(f"{name} started")
    while seconds > 0:
        print(f"{name}: {seconds}")
        time.sleep(1)
        seconds -= 1
    print(f"{name} finished")

timer1 = ("Timer 1", 10)
timer2 = ("Timer 2", 20)

thread1 = threading.Thread(target=countdown_timer, args=timer1)
thread2 = threading.Thread(target=countdown_timer, args=timer2)

thread1.start()
thread2.start()

thread1.join()
thread2.join()

print("Both timers have finished.")
# Out:
# Timer 1 started
# Timer 1: 10
# Timer 2 started
# Timer 2: 20
# Timer 2: 19Timer 1: 9
#
# Timer 1: 8Timer 2: 18
#
# Timer 2: 17
# Timer 1: 7
# Timer 1: 6Timer 2: 16
#
# Timer 2: 15
# Timer 1: 5
# Timer 2: 14Timer 1: 4
#
# Timer 1: 3
# Timer 2: 13
# Timer 1: 2
# Timer 2: 12
# Timer 1: 1Timer 2: 11
#
# Timer 2: 10
# Timer 1 finished
# Timer 2: 9
# Timer 2: 8
# Timer 2: 7
# Timer 2: 6
# Timer 2: 5
# Timer 2: 4
# Timer 2: 3
# Timer 2: 2
# Timer 2: 1
# Timer 2 finished
# Both timers have finished.

# %%
# Thread Synchronization Challenge

import threading

lock = threading.Lock()

def print_odd():
    for i in range(1, 11, 2):
        with lock:
            print(i)
            lock.notify()  
            lock.wait() 

def print_even():
    for i in range(2, 11, 2):
        with lock:
            print(i)
            lock.notify()  
            if i < 10:
                lock.wait() 

odd_thread = threading.Thread(target=print_odd)
even_thread = threading.Thread(target=print_even)
odd_thread.start()
even_thread.start()

odd_thread.join()
even_thread.join()
# Out:
# Exception in thread Thread-7 (print_odd):
# Traceback (most recent call last):
#   File "c:\Users\johna\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
# Exception in thread Thread-8 (print_even):
# Traceback (most recent call last):
#   File "c:\Users\johna\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\johna\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\johna\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self.run()
#   File "C:\Users\johna\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\johna\AppData\Local\Temp\ipykernel_29280\2603974971.py", line 11, in print_odd
#     _threading_Thread_run(self)
# ...

# %%
# Final Calculator Program for Basic Operations

# %%
# Complete Calculator GUI

import tkinter as tk
from tkinter import messagebox

def clear():
    entry.delete(0, tk.END)

def calculate():
    try:
        expression = entry.get()
        result = eval(expression)
        entry.delete(0, tk.END)
        entry.insert(tk.END, str(result))
    except ZeroDivisionError:
        messagebox.showerror("Error", "Cannot divide by zero")
    except Exception as e:
        messagebox.showerror("Error", str(e))

def add_to_expression(character):
    entry.insert(tk.END, character)

root = tk.Tk()
root.title("Calculator")

entry = tk.Entry(root, width=30, borderwidth=5)
entry.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

buttons = [
    ('7', 1, 0), ('8', 1, 1), ('9', 1, 2), ('/', 1, 3),
    ('4', 2, 0), ('5', 2, 1), ('6', 2, 2), ('*', 2, 3),
    ('1', 3, 0), ('2', 3, 1), ('3', 3, 2), ('-', 3, 3),
    ('0', 4, 0), ('.', 4, 1), ('=', 4, 2), ('+', 4, 3)
]

for (text, row, col) in buttons:
    btn = tk.Button(root, text=text, padx=20, pady=20, command=lambda text=text: add_to_expression(text))
    btn.grid(row=row, column=col)

clear_button = tk.Button(root, text='C', padx=20, pady=20, command=clear)
clear_button.grid(row=5, column=0, columnspan=3)

root.mainloop()

# %%
import tkinter as tk
from datetime import datetime

def update_time():
    current_time = datetime.now().strftime("%H:%M:%S")
    label.config(text=current_time)
    label.after(1000, update_time)  # Update every 1000 milliseconds (1 second)

# Create the main window
root = tk.Tk()
root.title("Digital Clock")

# Create a label to display the time
label = tk.Label(root, font=("Helvetica", 48), fg="black")
label.pack(padx=20, pady=20)

# Run the function to update time
update_time()

# Start the Tkinter event loop
root.mainloop()
